# %%
# !cat /home/gdholla1/projects/bias/data/derivatives/glm_fits_level3_no_ppi/grf_localmax_txt_file/_contrast_0_model_model1a/_threshold_2.6/_grf_cluster0/zstat1_localmax.txt
# Out:
# Cluster Index	Value	x	y	z

# %%
import glob

# %%
fns = glob.glob('/home/gdholla1/projects/bias/data/derivatives/glm_fits_level3_no_ppi/grf_localmax_txt_file/_contrast_*_model_model*/_threshold_2.3/_grf_cluster0/zstat1_localmax.txt')

# %%
from IPython.display import display

# %%
import pandas

# %%
for fn in sorted(fns):
    print fn
    display(pandas.read_csv(fn, sep='\t'))
# Out:
# /home/gdholla1/projects/bias/data/derivatives/glm_fits_level3_no_ppi/grf_localmax_txt_file/_contrast_0_model_model1a/_threshold_2.3/_grf_cluster0/zstat1_localmax.txt
# Empty DataFrame
# Columns: [Cluster Index, Value, x, y, z, Unnamed: 5]
# Index: []
# /home/gdholla1/projects/bias/data/derivatives/glm_fits_level3_no_ppi/grf_localmax_txt_file/_contrast_0_model_model1b/_threshold_2.3/_grf_cluster0/zstat1_localmax.txt
# Empty DataFrame
# Columns: [Cluster Index, Value, x, y, z, Unnamed: 5]
# Index: []
# /home/gdholla1/projects/bias/data/derivatives/glm_fits_level3_no_ppi/grf_localmax_txt_file/_contrast_0_model_model1c/_threshold_2.3/_grf_cluster0/zstat1_localmax.txt
# Empty DataFrame
# Columns: [Cluster Index, Value, x, y, z, Unnamed: 5]
# Index: []
# /home/gdholla1/projects/bias/data/derivatives/glm_fits_level3_no_ppi/grf_localmax_txt_file/_contrast_0_model_model2/_threshold_2.3/_grf_cluster0/zstat1_localmax.txt
# Empty DataFrame
# Columns: [Cluster Index, Value, x, y, z, Unnamed: 5]
# ...
