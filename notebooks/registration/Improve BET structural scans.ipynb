# %%
import nibabel as nb
from nipype.interfaces import fsl

# %% [markdown]
# # Subject 01

# %%
sns.set_context('poster')

# %%
subject_id = '01'
old = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w_old.nii.gz'.format(**locals())
new = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w.nii.gz'.format(**locals())

# %%
bet = fsl.BET()
bet.inputs.in_file = old
bet.inputs.out_file = new

bet.inputs.frac = 0.05
bet.inputs.vertical_gradient = 0.3
r = bet.run()

# %%
old_im = nb.load(old).get_data()
new_im = np.ma.masked_equal(nb.load(new).get_data(), 0)

plt.subplot(121)
plt.imshow(old_im[128, :, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[128, :, :].T, origin='lower', cmap=plt.cm.hot)

plt.subplot(122)
plt.imshow(old_im[:, 128, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[:, 128, :].T, origin='lower', cmap=plt.cm.hot)

# %% [markdown]
# # Subject 02

# %%
subject_id = '02'
old = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w_old.nii.gz'.format(**locals())
new = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w.nii.gz'.format(**locals())

# %%
bet = fsl.BET()
bet.inputs.in_file = old
bet.inputs.out_file = new

bet.inputs.frac = 0.06
bet.inputs.vertical_gradient = 0.0

# bet.robust = True
r = bet.run()

# %%
old_im = nb.load(old).get_data()
new_im = np.ma.masked_equal(nb.load(new).get_data(), 0)

plt.subplot(121)
plt.imshow(old_im[128, :, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[128, :, :].T, origin='lower', cmap=plt.cm.hot)

plt.subplot(122)
plt.imshow(old_im[:, 128, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[:, 128, :].T, origin='lower', cmap=plt.cm.hot)

# %% [markdown]
# # Subject 03

# %%
subject_id = '03'
old = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w_old.nii.gz'.format(**locals())
new = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w.nii.gz'.format(**locals())

# %%
bet = fsl.BET()
bet.inputs.in_file = old
bet.inputs.out_file = new

bet.inputs.frac = 0.07
bet.inputs.vertical_gradient = 0.15
r = bet.run()

# %%
old_im = nb.load(old).get_data()
new_im = np.ma.masked_equal(nb.load(new).get_data(), 0)

plt.subplot(121)
plt.imshow(old_im[128, :, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[128, :, :].T, origin='lower', cmap=plt.cm.hot)

plt.subplot(122)
plt.imshow(old_im[:, 128, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[:, 128, :].T, origin='lower', cmap=plt.cm.hot)

# %% [markdown]
# # Subject 04

# %%
subject_id = '04'
old = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w_old.nii.gz'.format(**locals())
new = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w.nii.gz'.format(**locals())

# %%
bet = fsl.BET()
bet.inputs.in_file = old
bet.inputs.out_file = new

bet.inputs.frac = 0.1
bet.inputs.vertical_gradient = 0.1
r = bet.run()

# %%
old_im = nb.load(old).get_data()
new_im = np.ma.masked_equal(nb.load(new).get_data(), 0)

plt.subplot(121)
plt.imshow(old_im[128, :, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[128, :, :].T, origin='lower', cmap=plt.cm.hot)

plt.subplot(122)
plt.imshow(old_im[:, 128, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[:, 128, :].T, origin='lower', cmap=plt.cm.hot)

# %% [markdown]
# # Subject 05

# %%
subject_id = '05'
old = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w_old.nii.gz'.format(**locals())
new = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w.nii.gz'.format(**locals())

# %%
bet = fsl.BET()
bet.inputs.in_file = old
bet.inputs.out_file = new

bet.inputs.frac = 0.1
bet.inputs.vertical_gradient = 0.1
r = bet.run()

# %%
old_im = nb.load(old).get_data()
new_im = np.ma.masked_equal(nb.load(new).get_data(), 0)

plt.subplot(121)
plt.imshow(old_im[128, :, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[128, :, :].T, origin='lower', cmap=plt.cm.hot)

plt.subplot(122)
plt.imshow(old_im[:, 128, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[:, 128, :].T, origin='lower', cmap=plt.cm.hot)

# %% [markdown]
# # Subject 06

# %%
bet = fsl.BET()
bet.inputs.in_file = '/home/gdholla1/projects/bias/data/raw/sub-06/anat/sub-06_T1w_old.nii.gz'
bet.inputs.out_file = '/home/gdholla1/projects/bias/data/raw/sub-06/anat/sub-06_T1w.nii.gz'

bet.inputs.frac = 0.075
bet.inputs.vertical_gradient = 0.5
r = bet.run()

# %%
old = nb.load('/home/gdholla1/projects/bias/data/raw/sub-06/anat/sub-06_T1w_old.nii.gz').get_data()
new = np.ma.masked_equal(nb.load('/home/gdholla1/projects/bias/data/raw/sub-06/anat/sub-06_T1w.nii.gz').get_data(), 0)

plt.imshow(old[128, :, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new[128, :, :].T, origin='lower', cmap=plt.cm.hot)

# %% [markdown]
# # Subject 07

# %%
bet = fsl.BET()
bet.inputs.in_file = '/home/gdholla1/projects/bias/data/raw/sub-07/anat/sub-07_T1w_old.nii.gz'
bet.inputs.out_file = '/home/gdholla1/projects/bias/data/raw/sub-07/anat/sub-07_T1w.nii.gz'

bet.inputs.frac = 0.12
bet.inputs.vertical_gradient = 0.3
r = bet.run()

# %%
old = nb.load('/home/gdholla1/projects/bias/data/raw/sub-07/anat/sub-07_T1w_old.nii.gz').get_data()
new = np.ma.masked_equal(nb.load('/home/gdholla1/projects/bias/data/raw/sub-07/anat/sub-07_T1w.nii.gz').get_data(), 0)

plt.imshow(old[128, :, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new[128, :, :].T, origin='lower', cmap=plt.cm.hot)

# %% [markdown]
# # Subject 08

# %%
bet = fsl.BET()
bet.inputs.in_file = '/home/gdholla1/projects/bias/data/raw/sub-08/anat/sub-08_T1w_old.nii.gz'
bet.inputs.out_file = '/home/gdholla1/projects/bias/data/raw/sub-08/anat/sub-08_T1w.nii.gz'

bet.inputs.frac = 0.05
bet.inputs.vertical_gradient = 0.5
r = bet.run()

# %%
old = nb.load('/home/gdholla1/projects/bias/data/raw/sub-08/anat/sub-08_T1w_old.nii.gz').get_data()
new = np.ma.masked_equal(nb.load('/home/gdholla1/projects/bias/data/raw/sub-08/anat/sub-08_T1w.nii.gz').get_data(), 0)

plt.imshow(old[128, :, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new[128, :, :].T, origin='lower', cmap=plt.cm.hot)

# %% [markdown]
# # Subject 09

# %%
subject_id = '09'
old = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w_old.nii.gz'.format(**locals())
new = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w.nii.gz'.format(**locals())

# %%
bet = fsl.BET()
bet.inputs.in_file = old
bet.inputs.out_file = new

bet.inputs.frac = 0.05
bet.inputs.vertical_gradient = 0.3
r = bet.run()

# %%
sns.set_context('poster')

# %%
old_im = nb.load(old).get_data()
new_im = np.ma.masked_equal(nb.load(new).get_data(), 0)

plt.imshow(old_im[128, :, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[128, :, :].T, origin='lower', cmap=plt.cm.hot)

# %% [markdown]
# # Subject 10

# %%
subject_id = '10'
old = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w_old.nii.gz'.format(**locals())
new = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w.nii.gz'.format(**locals())

# %%
bet = fsl.BET()
bet.inputs.in_file = old
bet.inputs.out_file = new

bet.inputs.frac = 0.15
bet.inputs.vertical_gradient = 0.1
r = bet.run()

# %%
old_im = nb.load(old).get_data()
new_im = np.ma.masked_equal(nb.load(new).get_data(), 0)

plt.subplot(121)
plt.imshow(old_im[128, :, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[128, :, :].T, origin='lower', cmap=plt.cm.hot)

plt.subplot(122)
plt.imshow(old_im[:, 128, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[:, 128, :].T, origin='lower', cmap=plt.cm.hot)

# %% [markdown]
# # Subject 11

# %%
subject_id = '11'
old = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w_old.nii.gz'.format(**locals())
new = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w.nii.gz'.format(**locals())

# %%
bet = fsl.BET()
bet.inputs.in_file = old
bet.inputs.out_file = new

bet.inputs.frac = 0.14
bet.inputs.vertical_gradient = 0.3
r = bet.run()

# %%
old_im = nb.load(old).get_data()
new_im = np.ma.masked_equal(nb.load(new).get_data(), 0)

plt.imshow(old_im[128, :, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[128, :, :].T, origin='lower', cmap=plt.cm.hot)

# %% [markdown]
# # Subject 12

# %%
subject_id = '12'
old = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w_old.nii.gz'.format(**locals())
new = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w.nii.gz'.format(**locals())

# %%
bet = fsl.BET()
bet.inputs.in_file = old
bet.inputs.out_file = new

bet.inputs.frac = 0.14
bet.inputs.vertical_gradient = 0.3
r = bet.run()

# %%
old_im = nb.load(old).get_data()
new_im = np.ma.masked_equal(nb.load(new).get_data(), 0)

plt.imshow(old_im[128, :, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[128, :, :].T, origin='lower', cmap=plt.cm.hot)

# %% [markdown]
# # Subject 13

# %%
subject_id = '13'
old = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w_old.nii.gz'.format(**locals())
new = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w.nii.gz'.format(**locals())

# %%
bet = fsl.BET()
bet.inputs.in_file = old
bet.inputs.out_file = new

bet.inputs.frac = 0.14
bet.inputs.vertical_gradient = 0.2
r = bet.run()

# %%
old_im = nb.load(old).get_data()
new_im = np.ma.masked_equal(nb.load(new).get_data(), 0)

plt.imshow(old_im[128, :, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[128, :, :].T, origin='lower', cmap=plt.cm.hot)

# %% [markdown]
# # Subject 14

# %%
subject_id = '14'
old = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w_old.nii.gz'.format(**locals())
new = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w.nii.gz'.format(**locals())

# %%
bet = fsl.BET()
bet.inputs.in_file = old
bet.inputs.out_file = new

bet.inputs.frac = 0.075
bet.inputs.vertical_gradient = 0.3
r = bet.run()

# %%
old_im = nb.load(old).get_data()
new_im = np.ma.masked_equal(nb.load(new).get_data(), 0)

plt.imshow(old_im[128, :, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[128, :, :].T, origin='lower', cmap=plt.cm.hot)

# %% [markdown]
# # Subject 15

# %%
subject_id = '15'
old = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w_old.nii.gz'.format(**locals())
new = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w.nii.gz'.format(**locals())

# %%
bet = fsl.BET()
bet.inputs.in_file = old
bet.inputs.out_file = new

bet.inputs.frac = 0.1
bet.inputs.vertical_gradient = 0.3
r = bet.run()

# %%
old_im = nb.load(old).get_data()
new_im = np.ma.masked_equal(nb.load(new).get_data(), 0)

plt.subplot(121)
plt.imshow(old_im[128, :, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[128, :, :].T, origin='lower', cmap=plt.cm.hot)

plt.subplot(122)
plt.imshow(old_im[:, 128, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[:, 128, :].T, origin='lower', cmap=plt.cm.hot)

# %% [markdown]
# # Subject 16

# %%
subject_id = '16'
old = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w_old.nii.gz'.format(**locals())
new = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w.nii.gz'.format(**locals())

# %%
bet = fsl.BET()
bet.inputs.in_file = old
bet.inputs.out_file = new

bet.inputs.frac = 0.1
bet.inputs.vertical_gradient = 0.3
r = bet.run()

# %%
old_im = nb.load(old).get_data()
new_im = np.ma.masked_equal(nb.load(new).get_data(), 0)

plt.subplot(121)
plt.imshow(old_im[128, :, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[128, :, :].T, origin='lower', cmap=plt.cm.hot)

plt.subplot(122)
plt.imshow(old_im[:, 128, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[:, 128, :].T, origin='lower', cmap=plt.cm.hot)

# %% [markdown]
# # Subject 18

# %%
subject_id = '18'
old = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w_old.nii.gz'.format(**locals())
new = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w.nii.gz'.format(**locals())

# %%
bet = fsl.BET()
bet.inputs.in_file = old
bet.inputs.out_file = new

bet.inputs.frac = 0.1
bet.inputs.vertical_gradient = 0.3
r = bet.run()

# %%
old_im = nb.load(old).get_data()
new_im = np.ma.masked_equal(nb.load(new).get_data(), 0)

plt.subplot(121)
plt.imshow(old_im[128, :, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[128, :, :].T, origin='lower', cmap=plt.cm.hot)

plt.subplot(122)
plt.imshow(old_im[:, 128, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[:, 128, :].T, origin='lower', cmap=plt.cm.hot)

# %% [markdown]
# # Subject 19

# %%
subject_id = '19'
old = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w_old.nii.gz'.format(**locals())
new = '/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w.nii.gz'.format(**locals())

# %%
bet = fsl.BET()
bet.inputs.in_file = old
bet.inputs.out_file = new

bet.inputs.frac = 0.1
bet.inputs.vertical_gradient = 0.3
r = bet.run()

# %%
old_im = nb.load(old).get_data()
new_im = np.ma.masked_equal(nb.load(new).get_data(), 0)

plt.subplot(121)
plt.imshow(old_im[128, :, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[128, :, :].T, origin='lower', cmap=plt.cm.hot)

plt.subplot(122)
plt.imshow(old_im[:, 128, :].T, origin='lower', cmap=plt.cm.gray)
plt.imshow(new_im[:, 128, :].T, origin='lower', cmap=plt.cm.hot)
